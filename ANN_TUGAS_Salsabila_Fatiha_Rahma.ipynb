# %% [markdown]
# <a href="https://colab.research.google.com/github/Safayaa24/SalsabilaFatiha17/blob/main/ANN_TUGAS_Salsabila_Fatiha_Rahma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Salsbila Fatiha Rahma
# 5311422081

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score

# %%
df = pd.read_csv('car_purchasing.csv', encoding='ISO-8859-1')
df.head()
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# 2  638467.1773          42925.70921
# 3  548599.0524          67422.36313
# 4  560304.0671          55915.46248

# %%
df.drop(columns=['customer name', 'customer e-mail', 'country', 'gender'], inplace=True)

# %%
df.head()
# Out:
#          age  annual Salary  credit card debt    net worth  \
# 0  41.851720    62812.09301      11609.380910  238961.2505
# 1  40.870623    66646.89292       9572.957136  530973.9078
# 2  43.152897    53798.55112      11160.355060  638467.1773
# 3  58.271369    79370.03798      14426.164850  548599.0524
# 4  57.313749    59729.15130       5358.712177  560304.0671
#
#    car purchase amount
# 0          35321.45877
# 1          45115.52566
# 2          42925.70921
# 3          67422.36313
# 4          55915.46248

# %%
df.info()
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  500 non-null    float64
#  1   annual Salary        500 non-null    float64
#  2   credit card debt     500 non-null    float64
#  3   net worth            500 non-null    float64
#  4   car purchase amount  500 non-null    float64
# dtypes: float64(5)
# memory usage: 19.7 KB
# age                    0
# annual Salary          0
# credit card debt       0
# net worth              0
# car purchase amount    0
# dtype: int64

# %%
plt.scatter(df['annual Salary'] , df['credit card debt'])
plt.xlabel('annual Salary')
plt.ylabel('credit card debt')
plt.title('the corr between credit card debt and annual Salary')
# Out:
# Text(0.5, 1.0, 'the corr between credit card debt and annual Salary')

# %%
sns.pairplot(df)

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
scale = MinMaxScaler()
X = scale.fit_transform(X)
y = scale.fit_transform(y.values.reshape(-1, 1))
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)

# %% [markdown]
# linear regression

# %%
#Trying linear regression
lreg = LinearRegression()
lreg.fit(X_train, y_train)
print('Train score', lreg.score(X_train, y_train))
print('Test score', lreg.score(X_test, y_test))
# Out:
# Train score 0.999999981848654
# Test score 0.9999999781869485

# %%
y_pred = lreg.predict(X_test)

# %% [markdown]
# ANN MODEL

# %%
ann = Sequential([Dense(32, activation="relu"),
                 Dense(1, activation='linear')])

ann.compile(optimizer='adam',
            loss='mean_squared_error',
            metrics=['mean_absolute_error'])


history = ann.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 26ms/step - loss: 0.2368 - mean_absolute_error: 0.4589 - val_loss: 0.1650 - val_mean_absolute_error: 0.3842
# Epoch 2/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1065 - mean_absolute_error: 0.2939 - val_loss: 0.0610 - val_mean_absolute_error: 0.2235
# Epoch 3/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0367 - mean_absolute_error: 0.1602 - val_loss: 0.0174 - val_mean_absolute_error: 0.1058
# Epoch 4/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0148 - mean_absolute_error: 0.0978 - val_loss: 0.0091 - val_mean_absolute_error: 0.0750
# Epoch 5/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0129 - mean_absolute_error: 0.0911 - val_loss: 0.0096 - val_mean_absolute_error: 0.0786
# Epoch 6/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0128 - mean_absolute_error: 0.0911 - val_loss: 0.0089 - val_mean_absolute_error: 0.0753
# Epoch 7/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0116 - mean_absolute_error: 0.0861 - val_loss: 0.0082 - val_mean_absolute_error: 0.0717
# Epoch 8/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0106 - mean_absolute_error: 0.0823 - val_loss: 0.0078 - val_mean_absolute_error: 0.0700
# Epoch 9/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0100 - mean_absolute_error: 0.0796 - val_loss: 0.0075 - val_mean_absolute_error: 0.0684
# Epoch 10/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0091 - mean_absolute_error: 0.0761 - val_loss: 0.0070 - val_mean_absolute_error: 0.0664
# Epoch 11/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0083 - mean_absolute_error: 0.0725 - val_loss: 0.0064 - val_mean_absolute_error: 0.0638
# Epoch 12/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0076 - mean_absolute_error: 0.0693 - val_loss: 0.0059 - val_mean_absolute_error: 0.0615
# Epoch 13/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0067 - mean_absolute_error: 0.0656 - val_loss: 0.0053 - val_mean_absolute_error: 0.0580
# Epoch 14/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0061 - mean_absolute_error: 0.0622 - val_loss: 0.0048 - val_mean_absolute_error: 0.0556
# Epoch 15/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0055 - mean_absolute_error: 0.0589 - val_loss: 0.0043 - val_mean_absolute_error: 0.0531
# Epoch 16/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0050 - mean_absolute_error: 0.0560 - val_loss: 0.0040 - val_mean_absolute_error: 0.0503
# Epoch 17/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0045 - mean_absolute_error: 0.0536 - val_loss: 0.0037 - val_mean_absolute_error: 0.0483
# Epoch 18/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0042 - mean_absolute_error: 0.0516 - val_loss: 0.0034 - val_mean_absolute_error: 0.0466
# Epoch 19/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0037 - mean_absolute_error: 0.0487 - val_loss: 0.0032 - val_mean_absolute_error: 0.0447
# Epoch 20/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0034 - mean_absolute_error: 0.0465 - val_loss: 0.0029 - val_mean_absolute_error: 0.0428
# Epoch 21/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0031 - mean_absolute_error: 0.0445 - val_loss: 0.0027 - val_mean_absolute_error: 0.0410
# Epoch 22/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0029 - mean_absolute_error: 0.0425 - val_loss: 0.0025 - val_mean_absolute_error: 0.0396
# Epoch 23/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0026 - mean_absolute_error: 0.0408 - val_loss: 0.0022 - val_mean_absolute_error: 0.0379
# Epoch 24/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0024 - mean_absolute_error: 0.0388 - val_loss: 0.0021 - val_mean_absolute_error: 0.0371
# Epoch 25/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0022 - mean_absolute_error: 0.0371 - val_loss: 0.0019 - val_mean_absolute_error: 0.0344
# Epoch 26/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0020 - mean_absolute_error: 0.0353 - val_loss: 0.0017 - val_mean_absolute_error: 0.0331
# Epoch 27/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0018 - mean_absolute_error: 0.0334 - val_loss: 0.0015 - val_mean_absolute_error: 0.0307
# Epoch 28/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0016 - mean_absolute_error: 0.0316 - val_loss: 0.0013 - val_mean_absolute_error: 0.0290
# Epoch 29/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0014 - mean_absolute_error: 0.0298 - val_loss: 0.0012 - val_mean_absolute_error: 0.0273
# Epoch 30/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0013 - mean_absolute_error: 0.0281 - val_loss: 0.0010 - val_mean_absolute_error: 0.0256
# Epoch 31/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0011 - mean_absolute_error: 0.0261 - val_loss: 8.8933e-04 - val_mean_absolute_error: 0.0239
# Epoch 32/50
# 10/10 [==============================] - 0s 8ms/step - loss: 9.4998e-04 - mean_absolute_error: 0.0246 - val_loss: 7.7557e-04 - val_mean_absolute_error: 0.0223
# Epoch 33/50
# 10/10 [==============================] - 0s 8ms/step - loss: 8.3939e-04 - mean_absolute_error: 0.0229 - val_loss: 6.7193e-04 - val_mean_absolute_error: 0.0207
# Epoch 34/50
# 10/10 [==============================] - 0s 7ms/step - loss: 7.2667e-04 - mean_absolute_error: 0.0213 - val_loss: 5.9050e-04 - val_mean_absolute_error: 0.0193
# Epoch 35/50
# 10/10 [==============================] - 0s 8ms/step - loss: 6.3031e-04 - mean_absolute_error: 0.0197 - val_loss: 5.1340e-04 - val_mean_absolute_error: 0.0181
# Epoch 36/50
# 10/10 [==============================] - 0s 10ms/step - loss: 5.5317e-04 - mean_absolute_error: 0.0186 - val_loss: 4.4605e-04 - val_mean_absolute_error: 0.0168
# Epoch 37/50
# 10/10 [==============================] - 0s 8ms/step - loss: 4.7383e-04 - mean_absolute_error: 0.0169 - val_loss: 3.9278e-04 - val_mean_absolute_error: 0.0157
# Epoch 38/50
# 10/10 [==============================] - 0s 7ms/step - loss: 4.0836e-04 - mean_absolute_error: 0.0157 - val_loss: 3.3156e-04 - val_mean_absolute_error: 0.0144
# Epoch 39/50
# 10/10 [==============================] - 0s 9ms/step - loss: 3.5050e-04 - mean_absolute_error: 0.0144 - val_loss: 2.8540e-04 - val_mean_absolute_error: 0.0133
# Epoch 40/50
# 10/10 [==============================] - 0s 10ms/step - loss: 3.0404e-04 - mean_absolute_error: 0.0133 - val_loss: 2.4218e-04 - val_mean_absolute_error: 0.0122
# Epoch 41/50
# 10/10 [==============================] - 0s 9ms/step - loss: 2.6310e-04 - mean_absolute_error: 0.0123 - val_loss: 2.0361e-04 - val_mean_absolute_error: 0.0112
# Epoch 42/50
# 10/10 [==============================] - 0s 9ms/step - loss: 2.2774e-04 - mean_absolute_error: 0.0115 - val_loss: 1.8478e-04 - val_mean_absolute_error: 0.0106
# Epoch 43/50
# 10/10 [==============================] - 0s 6ms/step - loss: 1.9397e-04 - mean_absolute_error: 0.0104 - val_loss: 1.5421e-04 - val_mean_absolute_error: 0.0097
# Epoch 44/50
# 10/10 [==============================] - 0s 7ms/step - loss: 1.6843e-04 - mean_absolute_error: 0.0096 - val_loss: 1.4186e-04 - val_mean_absolute_error: 0.0092
# Epoch 45/50
# 10/10 [==============================] - 0s 6ms/step - loss: 1.5006e-04 - mean_absolute_error: 0.0090 - val_loss: 1.1756e-04 - val_mean_absolute_error: 0.0083
# Epoch 46/50
# 10/10 [==============================] - 0s 8ms/step - loss: 1.2991e-04 - mean_absolute_error: 0.0082 - val_loss: 1.0349e-04 - val_mean_absolute_error: 0.0077
# Epoch 47/50
# 10/10 [==============================] - 0s 8ms/step - loss: 1.1773e-04 - mean_absolute_error: 0.0078 - val_loss: 9.1514e-05 - val_mean_absolute_error: 0.0072
# Epoch 48/50
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0890e-04 - mean_absolute_error: 0.0075 - val_loss: 8.8187e-05 - val_mean_absolute_error: 0.0070
# Epoch 49/50
# 10/10 [==============================] - 0s 7ms/step - loss: 9.7081e-05 - mean_absolute_error: 0.0070 - val_loss: 7.3359e-05 - val_mean_absolute_error: 0.0064
# Epoch 50/50
# 10/10 [==============================] - 0s 11ms/step - loss: 8.8928e-05 - mean_absolute_error: 0.0066 - val_loss: 6.9956e-05 - val_mean_absolute_error: 0.0062

# %%
tr_acc = history.history['mean_absolute_error']
tr_loss = history.history['loss']
val_acc = history.history['val_mean_absolute_error']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmin(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')
plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %%
ann_y_pred = ann.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 4ms/step

# %%
r2 = r2_score(y_test, y_pred)
print('R2 score:', r2)
# Out:
# R2 score: 0.9999999781869485

# %%
ann.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 8.1288e-05 - mean_absolute_error: 0.0069
# [8.128849731292576e-05, 0.006854821462184191]

# %%
ann.predict([[40, 70000.500, 9550,534000]])
# Out:
# 1/1 [==============================] - 0s 37ms/step
# array([[228105.94]], dtype=float32)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, label='Linear Regression')
plt.scatter(y_test, ann_y_pred, label='ANN')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='gray')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Predicted vs. Actual Values')
plt.legend()
plt.show()

# %%
# Konversi y_test ke biner
y_test_binary = (y_test_binary >= 0.5).astype(int)

# %%
# Predicting the test set results
y_pred = lreg.predict(X_test)
y_pred_binary = (y_pred_binary > 0.5).astype(int)  # Mengonversi prediksi ke biner

# %%
# confusion matrix
cmap1 = sns.diverging_palette(275,150,  s=40, l=65, n=6)
plt.subplots(figsize=(12,8))
cf_matrix = confusion_matrix(y_test_binary, y_pred_binary)
sns.heatmap(cf_matrix/np.sum(cf_matrix), cmap = cmap1, annot = True, annot_kws = {'size':15})
# Out:
# <Axes: >

# %%
# classification report
print(classification_report(y_test_binary, y_pred_binary))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        56
#            1       1.00      1.00      1.00        44
#
#     accuracy                           1.00       100
#    macro avg       1.00      1.00      1.00       100
# weighted avg       1.00      1.00      1.00       100
